# %% [markdown]
# # Senate_25 EDA

# %%
import pandas as pd

# %%
df = pd.read_csv("../datasets/senate25-final_updated.csv")

# %% [markdown]
# ## Columns
# Senate25 has 92822 rows and 78 columns

# %%
print("The dataset has the following amount of columns and rows:", df.shape)
# Out:
# The database has the following amount of columns and rows: (92822, 78)

# %% [markdown]
# ### Data types of each column:
# - The object data types describe where the voting took place
# - The rest of the data types present are numeric
#     - MachineID -> Id of the vote counting machine used in the precinct
#     - registeredVoters, actualVoters, validBallot, overVotes, underVotes -> Numeric valeus which dictate how many reigstered voters there were in that area, how many ballots were valid, and how many votes went over, under, and the resulting obtained votes
#     - The rest of the columns are for each of the candidates prsent in this election.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92822 entries, 0 to 92821
# Data columns (total 78 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   region                              92822 non-null  object
#  1   province                            92822 non-null  object
#  2   municipality                        92822 non-null  object
#  3   barangay                            92822 non-null  object
#  4   machineId                           92822 non-null  int64
#  5   registeredVoters                    92822 non-null  int64
#  6   actualVoters                        92822 non-null  int64
#  7   validBallot                         92822 non-null  int64
#  8   overVotes                           92822 non-null  int64
#  9   underVotes                          92822 non-null  int64
#  10  validVotes                          92822 non-null  int64
#  11  obtainedVotes                       92822 non-null  int64
#  12  1. ABALOS, BENHUR (PFP)             92822 non-null  int64
#  13  2. ADONIS, JEROME (MKBYN)           92822 non-null  int64
#  14  3. AMAD, WILSON (IND)               92822 non-null  int64
#  15  4. ANDAMO, NARS ALYN (MKBYN)        92822 non-null  int64
#  16  5. AQUINO, BAM (KNP)                92822 non-null  int64
#  17  6. ARAMBULO, RONNEL (MKBYN)         92822 non-null  int64
#  18  7. ARELLANO, ERNESTO (KTPNAN)       92822 non-null  int64
#  19  8. BALLON, ROBERTO (IND)            92822 non-null  int64
#  20  9. BINAY, ABBY (NPC)                92822 non-null  int64
#  21  10. BONDOC, JIMMY (PDPLBN)          92822 non-null  int64
#  22  11. BONG REVILLA,RAMON, JR.(LAKAS)  92822 non-null  int64
#  23  12. BOSITA, COLONEL (IND)           92822 non-null  int64
#  24  13. BROSAS, ARLENE (MKBYN)          92822 non-null  int64
#  25  14. CABONEGRO, ROY (DPP)            92822 non-null  int64
#  26  15. CAPUYAN, ALLEN (PPP)            92822 non-null  int64
#  27  16. CASIÑO, TEDDY (MKBYN)           92822 non-null  int64
#  28  17. CASTRO, TEACHER FRANCE (MKBYN)  92822 non-null  int64
#  29  18. CAYETANO, PIA (NP)              92822 non-null  int64
#  30  19. D'ANGELO, DAVID (BUNYOG)        92822 non-null  int64
#  31  20. DE ALBAN,ATTORNEY ANGELO (IND)  92822 non-null  int64
#  32  21. DE GUZMAN, KA LEODY (PLM)       92822 non-null  int64
#  33  22. DELA ROSA, BATO (PDPLBN)        92822 non-null  int64
#  34  23. DORINGO, NANAY MIMI (MKBYN)     92822 non-null  int64
#  35  24. ESCOBAL, ARNEL (PM)             92822 non-null  int64
#  36  25. ESPIRITU, LUKE (PLM)            92822 non-null  int64
# ### Viewing the first 10 records
# - Data seems to be valid and complete
# - Might be nice to consider collapsing underVotes and validBallot into one as they are both still counted as valid to total votes
# - Should also consider renaming the columns from camelCase to snake_case for readability and consistency throughout the project

# %%
print(df.head(10))
# Out:
#      region    province     municipality       barangay  machineId  \
# 0  REGION I  PANGASINAN         CALASIAO        NALSIAN   55170067
# 1  REGION I  PANGASINAN         CALASIAO       TALIBAEW   55170088
# 2  REGION I  PANGASINAN         BINMALEY          LINOC   55130045
# 3  REGION I  PANGASINAN        BINALONAN  STA. CATALINA   55120045
# 4  REGION I  PANGASINAN        BAYAMBANG         TAMPOG   55110109
# 5  REGION I  PANGASINAN         CALASIAO     CABILOCAAN   55170030
# 6  REGION I  PANGASINAN         BUGALLON      MAGTAKING   55150039
# 7  REGION I  PANGASINAN          BOLINAO   LUCIENTE 1.0   55140039
# 8  REGION I  PANGASINAN  CITY OF DAGUPAN    BACAYAO SUR   55180008
# 9  REGION I  PANGASINAN        BINALONAN           BUED   55120012
#
#    registeredVoters  actualVoters  validBallot  overVotes  underVotes  ...  \
# 0               862           645          776        252        1897  ...
# 1               821           677          719        336        2457  ...
# 2               932           767          817        312        2461  ...
# 3               662           592          625        120        3016  ...
# 4               960           788          852        480        2469  ...
# 5               683           596          735        192        2773  ...
# 6               943           842         1202        276        4072  ...
# 7               832           740          773        372        2488  ...
# 8               863           737          789        360        1695  ...
# 9               631           534          589        168        2418  ...
#
#    57. SAHIDULLA, NUR-ANA (IND)  58. SALVADOR, PHILLIP IPE (PDPLBN)  \
# 0                             0                                  49
# 1                             3                                  63
# 2                             8                                  78
# 3                             1                                  36
# 4                             4                                  82
# 5                             4                                  41
# 6                             5                                  57
# 7                             0                                  63
# 8                             5                                  75
# 9                             2                                  33
#
#    59. SOTTO, TITO (NPC)  60. TAPADO, MICHAEL BONGBONG (PM)  \
# 0                    176                                  4
# 1                    250                                  7
# 2                    289                                  9
# 3                    125                                  3
# 4                    292                                 15
# 5                    171                                  7
# 6                    250                                 10
# 7                    295                                  8
# 8                    262                                 10
# 9                    183                                  5
#
#    61. TOLENTINO, FRANCIS TOL (PFP)  62. TULFO, BEN BITAG (IND)  \
# 0                                83                         158
# 1                                80                         178
# 2                               122                         228
# 3                               164                         119
# 4                               102                         295
# 5                                47                         175
# 6                                90                         220
# 7                               123                         217
# 8                               101                         231
# 9                                91                         175
#
#    63. TULFO, ERWIN (LAKAS)  64. VALBUENA, MAR MANIBELA (IND)  \
# 0                       194                                 7
# 1                       251                                 4
# 2                       315                                 6
# 3                       163                                 1
# 4                       333                                 9
# 5                       217                                 7
# 6                       272                                 4
# 7                       288                                11
# 8                       290                                17
# 9                       224                                 4
#
#    65. VERCELES, LEANDRO (IND)  66. VILLAR, CAMILLE (NP)
# 0                            6                       110
# 1                            3                       179
# 2                            6                       190
# 3                            0                       176
# 4                            5                       239
# 5                            4                       127
# 6                            5                       180
# 7                            6                       320
# 8                            5                       254
# 9                            2                       135
#
# [10 rows x 78 columns]

# %% [markdown]
# ## Checking for Null
# - All rows have no NULL's present, hence the 'False' marking

# %%
print(pd.isnull(df))
# Out:
#        region  province  municipality  barangay  machineId  registeredVoters  \
# 0       False     False         False     False      False             False
# 1       False     False         False     False      False             False
# 2       False     False         False     False      False             False
# 3       False     False         False     False      False             False
# 4       False     False         False     False      False             False
# ...       ...       ...           ...       ...        ...               ...
# 92817   False     False         False     False      False             False
# 92818   False     False         False     False      False             False
# 92819   False     False         False     False      False             False
# 92820   False     False         False     False      False             False
# 92821   False     False         False     False      False             False
#
#        actualVoters  validBallot  overVotes  underVotes  ...  \
# 0             False        False      False       False  ...
# 1             False        False      False       False  ...
# 2             False        False      False       False  ...
# 3             False        False      False       False  ...
# 4             False        False      False       False  ...
# ...             ...          ...        ...         ...  ...
# 92817         False        False      False       False  ...
# 92818         False        False      False       False  ...
# 92819         False        False      False       False  ...
# 92820         False        False      False       False  ...
# 92821         False        False      False       False  ...
#
#        57. SAHIDULLA, NUR-ANA (IND)  58. SALVADOR, PHILLIP IPE (PDPLBN)  \
# 0                             False                               False
# 1                             False                               False
# 2                             False                               False
# 3                             False                               False
# 4                             False                               False
# ...                             ...                                 ...
# 92817                         False                               False
# 92818                         False                               False
# 92819                         False                               False
# 92820                         False                               False
# 92821                         False                               False
#
#        59. SOTTO, TITO (NPC)  60. TAPADO, MICHAEL BONGBONG (PM)  \
# 0                      False                              False
# 1                      False                              False
# 2                      False                              False
# 3                      False                              False
# 4                      False                              False
# ...                      ...                                ...
# 92817                  False                              False
# 92818                  False                              False
# 92819                  False                              False
# 92820                  False                              False
# 92821                  False                              False
#
#        61. TOLENTINO, FRANCIS TOL (PFP)  62. TULFO, BEN BITAG (IND)  \
# 0                                 False                       False
# 1                                 False                       False
# 2                                 False                       False
# 3                                 False                       False
# 4                                 False                       False
# ...                                 ...                         ...
# 92817                             False                       False
# 92818                             False                       False
# 92819                             False                       False
# 92820                             False                       False
# 92821                             False                       False
#
#        63. TULFO, ERWIN (LAKAS)  64. VALBUENA, MAR MANIBELA (IND)  \
# 0                         False                             False
# 1                         False                             False
# 2                         False                             False
# 3                         False                             False
# 4                         False                             False
# ...                         ...                               ...
# 92817                     False                             False
# 92818                     False                             False
# 92819                     False                             False
# 92820                     False                             False
# 92821                     False                             False
#
#        65. VERCELES, LEANDRO (IND)  66. VILLAR, CAMILLE (NP)
# 0                            False                     False
# 1                            False                     False
# 2                            False                     False
# 3                            False                     False
# 4                            False                     False
# ...                            ...                       ...
# 92817                        False                     False
# 92818                        False                     False
# 92819                        False                     False
# 92820                        False                     False
# 92821                        False                     False
#
# [92822 rows x 78 columns]

# %% [markdown]
# ## Checking unique values per column:

# %%
print("Unique count in region:", df['region'].nunique())
print("Unique count in province:", df['province'].nunique())
print("Unique count in municipality:", df['municipality'].nunique())
print("Unique count in barangay:", df['barangay'].nunique())
# Out:
# Unique count in region: 20
# Unique count in province: 92
# Unique count in municipality: 1478
# Unique count in barangay: 25592

# %% [markdown]
# - The region and province have a higher count than what the country actually has, this could be either our OAV or LAV votes
# - The count of barangay's may be lower compared to the total barangays in the phillipines because of COMELEC's Clustered Precinct System.
#     - To save on resources and money, COMELEC establishes a singular clustered precinct which can host multiple small barangays within the precincts general area.
