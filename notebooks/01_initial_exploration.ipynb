# %% [markdown]
# # Dataset Inital Exploration

# %%
import pandas as pd

# %%
df = pd.read_csv("../datasets/senate25-final_updated.csv")

# %% [markdown]
# ## Investigation of Columns

# %%
print(df.shape)
# Senate25 has 92822 rows and 78 columns
# Out:
# (92822, 78)

# %% [markdown]
# ### placeholder

# %%
print(df.head(1000))
# Out:
#         region    province   municipality       barangay  machineId  \
# 0     REGION I  PANGASINAN       CALASIAO        NALSIAN   55170067
# 1     REGION I  PANGASINAN       CALASIAO       TALIBAEW   55170088
# 2     REGION I  PANGASINAN       BINMALEY          LINOC   55130045
# 3     REGION I  PANGASINAN      BINALONAN  STA. CATALINA   55120045
# 4     REGION I  PANGASINAN      BAYAMBANG         TAMPOG   55110109
# ..         ...         ...            ...            ...        ...
# 995  REGION VI      ILOILO        BALASAN        PANI-AN   30050027
# 996  REGION VI      ILOILO      BADIANGAN         SARIRI   30040027
# 997  REGION VI      ILOILO  BAROTAC VIEJO         UGASAN   30080041
# 998  REGION VI      ILOILO           AJUY        TUBOGAN   30010052
# 999  REGION VI      ILOILO           AJUY  SANTO ROSARIO   30010044
#
#      registeredVoters  actualVoters  validBallot  overVotes  underVotes  ...  \
# 0                 862           645          776        252        1897  ...
# 1                 821           677          719        336        2457  ...
# 2                 932           767          817        312        2461  ...
# 3                 662           592          625        120        3016  ...
# 4                 960           788          852        480        2469  ...
# ..                ...           ...          ...        ...         ...  ...
# 995               627           550          585        168        2797  ...
# 996               439           369          389         84        2162  ...
# 997               818           730          839        144        4280  ...
# 998               470           405          421         96        1811  ...
# 999               777           685          711        144        4571  ...
#
#      57. SAHIDULLA, NUR-ANA (IND)  58. SALVADOR, PHILLIP IPE (PDPLBN)  \
# 0                               0                                  49
# 1                               3                                  63
# 2                               8                                  78
# 3                               1                                  36
# 4                               4                                  82
# ..                            ...                                 ...
# 995                             0                                  57
# 996                             2                                  29
# 997                             2                                  66
# 998                             1                                  52
# 999                             3                                  60
#
#      59. SOTTO, TITO (NPC)  60. TAPADO, MICHAEL BONGBONG (PM)  \
# 0                      176                                  4
# 1                      250                                  7
# 2                      289                                  9
# 3                      125                                  3
# 4                      292                                 15
# ..                     ...                                ...
# 995                    123                                  6
# 996                     91                                  0
# 997                    163                                 14
# 998                    100                                  6
# 999                    147                                  7
#
#      61. TOLENTINO, FRANCIS TOL (PFP)  62. TULFO, BEN BITAG (IND)  \
# 0                                  83                         158
# 1                                  80                         178
# 2                                 122                         228
# 3                                 164                         119
# 4                                 102                         295
# ..                                ...                         ...
# 995                                52                         133
# 996                                60                          54
# 997                                58                         116
# 998                                43                         140
# 999                                61                         148
#
#      63. TULFO, ERWIN (LAKAS)  64. VALBUENA, MAR MANIBELA (IND)  \
# 0                         194                                 7
# 1                         251                                 4
# 2                         315                                 6
# 3                         163                                 1
# 4                         333                                 9
# ..                        ...                               ...
# 995                       196                                 5
# 996                       105                                 0
# 997                       264                                 7
# 998                       221                                 4
# 999                       235                                11
#
#      65. VERCELES, LEANDRO (IND)  66. VILLAR, CAMILLE (NP)
# 0                              6                       110
# 1                              3                       179
# 2                              6                       190
# 3                              0                       176
# 4                              5                       239
# ..                           ...                       ...
# 995                            2                       177
# 996                            0                        74
# 997                            3                       151
# 998                            1                       143
# 999                            3                       147
#
# [1000 rows x 78 columns]
